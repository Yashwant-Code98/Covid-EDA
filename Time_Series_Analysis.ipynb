# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashwant-Code98/Covid-EDA/blob/master/Time_Series_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import files

# %%
electric = pd.read_csv("electric.csv")

# %%
# Checking Data Type Of Dataset
electric.dtypes
# Out:
# DATE      object
# Value    float64
# dtype: object

# %%
electric = pd.read_csv("electric.csv",parse_dates=["DATE"])

# %%
electric.dtypes
# Out:
# DATE     datetime64[ns]
# Value           float64
# dtype: object

# %%
electric = pd.read_csv("electric.csv",parse_dates=["DATE"],index_col=["DATE"])

# %%
electric.head()
# Out:
#               Value
# DATE
# 1985-01-01  72.5052
# 1985-02-01  70.6720
# 1985-03-01  62.4502
# 1985-04-01  57.4714
# 1985-05-01  55.3151

# %%
electric["1985-01-01":"1986-04-01"]
# Out:
#               Value
# DATE
# 1985-01-01  72.5052
# 1985-02-01  70.6720
# 1985-03-01  62.4502
# 1985-04-01  57.4714
# 1985-05-01  55.3151
# 1985-06-01  58.0904
# 1985-07-01  62.6202
# 1985-08-01  63.2485
# 1985-09-01  60.5846
# 1985-10-01  56.3154
# 1985-11-01  58.0005
# 1985-12-01  68.7145
# 1986-01-01  73.3057
# 1986-02-01  67.9869
# 1986-03-01  62.2221
# 1986-04-01  57.0329

# %%
electric.plot()
plt.show()

# %%
# Increase figure size !
from pylab import rcParams
rcParams["figure.figsize"]= 12,8
electric.plot()
plt.show()

# %%
 
#plt.figure(figsize=(15,10))
electric_mul_decompose = seasonal_decompose(electric,model="multiplicative")
electric_mul_decompose.plot()
plt.show()

# %%
electric_log = electric.copy()

# %%
import numpy as np

# %%
electric["Value"] = np.log(electric)

# %%
electric_log.Value
# Out:
# DATE
# 1985-01-01     72.5052
# 1985-02-01     70.6720
# 1985-03-01     62.4502
# 1985-04-01     57.4714
# 1985-05-01     55.3151
#                 ...
# 2017-09-01     98.6154
# 2017-10-01     93.6137
# 2017-11-01     97.3359
# 2017-12-01    114.7212
# 2018-01-01    129.4048
# Name: Value, Length: 397, dtype: float64

# %%
plt.subplot(2,1,1)
plt.title("Original Time Series")
plt.plot(electric)
 
plt.subplot(2,1,2)
plt.title("Log Transform Series")
plt.plot(electric_log)
plt.show()
