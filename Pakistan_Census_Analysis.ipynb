# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashwant-Code98/Covid-EDA/blob/master/Pakistan_Census_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-31b180a8-4d70-4277-a768-03983ccacb53" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31b180a8-4d70-4277-a768-03983ccacb53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving census.csv to census.csv

# %%
census = pd.read_csv("census.csv")

# %%
census.head()
# Out:
#    age          workclass  final-weight  ... hour-per-week  native-country  income
# 0   39          State-gov         77516  ...            40   United-States   <=50K
# 1   50   Self-emp-not-inc         83311  ...            13   United-States   <=50K
# 2   38            Private        215646  ...            40   United-States   <=50K
# 3   53            Private        234721  ...            40   United-States   <=50K
# 4   28            Private        338409  ...            40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
census["age"].value_counts()
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 85      3
# 88      3
# 87      1
# 86      1
# Name: age, Length: 73, dtype: int64

# %%
population_age=census.sort_values(by="age", ascending=False)

# %%
population_age.head()
# Out:
#        age workclass  final-weight  ... hour-per-week  native-country  income
# 5406    90   Private         51744  ...            50   United-States    >50K
# 6624    90   Private        313986  ...            40   United-States   <=50K
# 20610   90   Private        206667  ...            40   United-States    >50K
# 1040    90   Private        137018  ...            40   United-States   <=50K
# 1935    90   Private        221832  ...            45   United-States   <=50K
#
# [5 rows x 15 columns]

# %%
sns.histplot(census["age"],kde=True, color="olive")
plt.show()

# %%
census["workclass"].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
plt.figure(figsize=(15,10))
plt.bar(list(census["workclass"].value_counts().index),list(census["workclass"].value_counts()),color=["c"])
plt.show()

# %%
census["final-weight"].value_counts()
# Out:
# 164190    13
# 203488    13
# 123011    13
# 113364    12
# 121124    12
#           ..
# 284211     1
# 312881     1
# 177711     1
# 179758     1
# 229376     1
# Name: final-weight, Length: 21648, dtype: int64

# %%
sns.distplot(census["final-weight"],kde=True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
census["education"].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %%
plt.figure(figsize=(20,15))
plt.pie(list(census["education"].value_counts()),labels=list(census["education"].value_counts().index),autopct='%0.1f%%')
plt.show()

# %%
census["marital-status"].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %%
plt.figure(figsize=(15,10))
plt.bar(list(census["marital-status"].value_counts().keys()),list(census["marital-status"].value_counts()),color=["red","olive","yellow","orange","green","purple"])
plt.show()

# %%
census.head()
# Out:
#    age          workclass  final-weight  ... hour-per-week  native-country  income
# 0   39          State-gov         77516  ...            40   United-States   <=50K
# 1   50   Self-emp-not-inc         83311  ...            13   United-States   <=50K
# 2   38            Private        215646  ...            40   United-States   <=50K
# 3   53            Private        234721  ...            40   United-States   <=50K
# 4   28            Private        338409  ...            40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
census["occupation"].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
plt.figure(figsize=(25,20))
sns.histplot(census["occupation"],kde=True)
plt.show()

# %%
census["relationship"].value_counts()
# Out:
#  Husband           13193
#  Not-in-family      8305
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: relationship, dtype: int64

# %%
plt.figure(figsize=(15,10))
plt.pie(list(census["relationship"].value_counts()),labels=list(census["relationship"].value_counts().index), autopct="%0.1f%%")
plt.title("Distribution of Relationship")
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(list(census["race"].value_counts().index),list(census["race"].value_counts()),color=["purple"])
plt.show()

# %%
census["sex"].value_counts()
# Out:
#  Male      21790
#  Female    10771
# Name: sex, dtype: int64

# %%
sns.histplot(census["sex"],color="blue")
plt.show()

# %%
census["capital-gain"].value_counts()
# Out:
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 4931         1
# 1455         1
# 6097         1
# 22040        1
# 1111         1
# Name: capital-gain, Length: 119, dtype: int64

# %%
sns.histplot(census["capital-gain"])
plt.show()

# %%
census["capital-loos"].value_counts()
# Out:
# 0       31042
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 1411        1
# 1539        1
# 2472        1
# 1944        1
# 2201        1
# Name: capital-loos, Length: 92, dtype: int64

# %%
plt.figure(figsize=(15,10))
plt.hist(census["capital-loos"])
plt.show()

# %%
census["hour-per-week"].value_counts()
# Out:
# 40    15217
# 50     2819
# 45     1824
# 60     1475
# 35     1297
#       ...
# 92        1
# 94        1
# 87        1
# 74        1
# 82        1
# Name: hour-per-week, Length: 94, dtype: int64

# %%
sns.kdeplot(census["hour-per-week"],fill="b")
plt.show()

# %%
census["native-country"].value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
plt.figure(figsize=(5,5))
plt.bar(list(census["native-country"].value_counts().index),list(census["native-country"].value_counts()),color=["green"])
plt.show()

# %%
census["income"].value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: income, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.pie(list(census["income"].value_counts()),labels=list(census["income"].value_counts().index),autopct="%0.1f%%")
plt.show()

# %%
census.head()
# Out:
#    age          workclass  final-weight  ... hour-per-week  native-country  income
# 0   39          State-gov         77516  ...            40   United-States   <=50K
# 1   50   Self-emp-not-inc         83311  ...            13   United-States   <=50K
# 2   38            Private        215646  ...            40   United-States   <=50K
# 3   53            Private        234721  ...            40   United-States   <=50K
# 4   28            Private        338409  ...            40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
sns.lineplot(x="age",y="education",data=census)
plt.show()

# %%
sns.lineplot(x="age",y="education",data=census,hue="sex")
plt.show()

# %%
sns.barplot(x="sex",y="hour-per-week",data=census)
plt.show()

# %%
sns.barplot(x="sex",y="hour-per-week",data=census,hue="race")
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.scatter(x="hour-per-week",y="income",data=census)
plt.show()

# %%
sns.lineplot(x="race",y="hour-per-week",data=census)
plt.show()

# %%
 sns.lineplot(x="race",y="hour-per-week",data=census,hue="sex")
plt.show()

# %%
sns.barplot(x="age",y="marital-status",data=census)
plt.show()

# %%
sns.scatterplot(x="sex",y="education",data=census)
plt.show()

# %%
sns.barplot(x="age",y="occupation",data=census)
plt.show()

# %%
sns.lineplot(x="age",y="occupation",data=census,hue="race")
plt.show()

# %%
sns.lineplot(x="sex",y="occupation",data=census)
plt.show()

# %%
sns.lineplot(x="sex",y="occupation",data=census,hue="race")
plt.show()

# %%
census.head()
# Out:
#    age          workclass  final-weight  ... hour-per-week  native-country  income
# 0   39          State-gov         77516  ...            40   United-States   <=50K
# 1   50   Self-emp-not-inc         83311  ...            13   United-States   <=50K
# 2   38            Private        215646  ...            40   United-States   <=50K
# 3   53            Private        234721  ...            40   United-States   <=50K
# 4   28            Private        338409  ...            40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
sns.histplot(x="relationship",y="occupation",data=census)
plt.show()

# %%
sns.histplot(x="relationship",y="occupation",data=census,hue="race")
plt.show()
